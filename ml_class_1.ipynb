# %%
import pandas as pd 
import numpy as np

# %%
data_path = "D:\learn_java_script\SAHeart.csv"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Vibeshram Marappan\AppData\Local\Temp\ipykernel_34976\2617039911.py:1: SyntaxWarning: invalid escape sequence '\l'
#   data_path = "D:\learn_java_script\SAHeart.csv"

# %%
data = pd.read_csv(data_path)

# %%
data.head()
# Out:
#    row.names  sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0          1  160    12.00  5.73      23.11  Present     49    25.30    97.20
# 1          2  144     0.01  4.41      28.61   Absent     55    28.87     2.06
# 2          3  118     0.08  3.48      32.28  Present     52    29.14     3.81
# 3          4  170     7.50  6.41      38.03  Present     51    31.99    24.26
# 4          5  134    13.60  3.50      27.78  Present     60    25.99    57.34
#
#    age  chd
# 0   52    1
# 1   63    1
# 2   46    0
# 3   58    1
# 4   49    1

# %%
data.columns
# Out:
# Index(['row.names', 'sbp', 'tobacco', 'ldl', 'adiposity', 'famhist', 'typea',
#        'obesity', 'alcohol', 'age', 'chd'],
#       dtype='object')

# %%
data.size
# Out:
# 5082

# %%
data.shape
# Out:
# (462, 11)

# %%
data.tail()
# Out:
#      row.names  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  \
# 457        459  214      0.4   5.98      31.72   Absent     64    28.45
# 458        460  182      4.2   4.41      32.10   Absent     52    28.61
# 459        461  108      3.0   1.59      15.23   Absent     40    20.09
# 460        462  118      5.4  11.61      30.79   Absent     64    27.35
# 461        463  132      0.0   4.82      33.41  Present     62    14.70
#
#      alcohol  age  chd
# 457     0.00   58    0
# 458    18.72   52    1
# 459    26.64   55    0
# 460    23.97   40    0
# 461     0.00   46    1

# %%
data.drop("row.names", axis = 1, inplace = True)

# %%
data.columns
# Out:
# Index(['sbp', 'tobacco', 'ldl', 'adiposity', 'famhist', 'typea', 'obesity',
#        'alcohol', 'age', 'chd'],
#       dtype='object')

# %%
data['famhist'].value_counts()
# Out:
# famhist
# Absent     270
# Present    192
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['fmyhist'] = le.fit_transform(data['famhist'])

# %%
data.head()
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age  chd  \
# 0  160    12.00  5.73      23.11  Present     49    25.30    97.20   52    1
# 1  144     0.01  4.41      28.61   Absent     55    28.87     2.06   63    1
# 2  118     0.08  3.48      32.28  Present     52    29.14     3.81   46    0
# 3  170     7.50  6.41      38.03  Present     51    31.99    24.26   58    1
# 4  134    13.60  3.50      27.78  Present     60    25.99    57.34   49    1
#
#    fmyhist
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1

# %%
data.drop('famhist', axis = 1, inplace = True)

# %%
data['chd'].value_counts()
# Out:
# chd
# 0    302
# 1    160
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
val = data.drop("chd", axis = 1)
tar = data['chd']

# %%
os = RandomOverSampler()

# %%
os_val, os_tar = os.fit_resample(val, tar)

# %%
os_tar.value_counts()
# Out:
# chd
# 1    302
# 0    302
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
# data without oversampling

trdata, tsdata, trlab, tslab = train_test_split(val, tar, test_size = 0.20, random_state = 44)

# %%
print(trdata.shape)
print(trlab.shape)
print(tsdata.shape)
print(tslab.shape)
# Out:
# (369, 9)
# (369,)
# (93, 9)
# (93,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
# model without oversampling

model.fit(trdata, trlab)
# Out:
# c:\Users\Vibeshram Marappan\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
trpredict = model.predict(trdata)
tspredict = model.predict(tsdata)

# %%
# performance without oversampling
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
def performance(x,y):
    acc = round(accuracy_score(x,y), 4) * 100
    pre = round(precision_score(x,y), 4) * 100
    recall = round(recall_score(x,y), 4) * 100
    f1 = round(f1_score(x,y), 4) * 100
    print(f"acc     = {acc}\npre     = {pre}\nrecall  = {recall}\nf1    = {f1}")

# %%
performance(trlab, trpredict)
# Out:
# acc     = 73.98
# pre     = 65.91
# recall  = 46.77
# f1    = 54.72

# %%
performance(tslab, tspredict)
# Out:
# acc     = 65.59
# pre     = 56.67
# recall  = 47.22
# f1    = 51.519999999999996

# %%
otrdata, otsdata, otrlab, otslab = train_test_split(os_val, os_tar, test_size = 0.20, random_state= 33)

# %%
print(otrdata.shape)
print(otrlab.shape)
print(otsdata.shape)
print(otslab.shape)
# Out:
# (483, 9)
# (483,)
# (121, 9)
# (121,)

# %%
# model with oversampled data
omodel = LogisticRegression()

# %%
omodel.fit(otrdata, otrlab)
# Out:
# c:\Users\Vibeshram Marappan\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
otrpredict = omodel.predict(otrdata)
otspredict = omodel.predict(otsdata)

# %%
#performance for oversampled data
performance(otrlab, otrpredict)
# Out:
# acc     = 71.43
# pre     = 70.8
# recall  = 73.14
# f1    = 71.95

# %%
performance(otslab, otspredict)
# Out:
# acc     = 66.12
# pre     = 65.57
# recall  = 66.67
# f1    = 66.12

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# implement the feature importance method in the datasets
fs = RandomForestClassifier()

# %%
fs.fit(os_val, os_tar)
# Out:
# RandomForestClassifier()

# %%
selected_col = pd.DataFrame({ 
    "col": os_val.columns,
    "score":fs.feature_importances_
}).sort_values("score", ascending = False).head(6)['col'].to_list()

# %%
nwdata = data[selected_col]

# %%
nwdata.shape
# Out:
# (462, 6)

# %%
tar.shape
# Out:
# (462,)

# %%
nwdata.head()
# Out:
#    age  tobacco   ldl  adiposity  obesity  sbp
# 0   52    12.00  5.73      23.11    25.30  160
# 1   63     0.01  4.41      28.61    28.87  144
# 2   46     0.08  3.48      32.28    29.14  118
# 3   58     7.50  6.41      38.03    31.99  170
# 4   49    13.60  3.50      27.78    25.99  134

# %%
nos = RandomOverSampler()

# %%
nodata, notar = nos.fit_resample(nwdata, tar)

# %%
nodata.shape
# Out:
# (604, 6)

# %%
notar.shape
# Out:
# (604,)

# %%
ntrdata, ntsdata, ntrlab, ntslab = train_test_split(nodata, notar, test_size = 0.20, random_state = 55)

# %%
print(ntrdata.shape)
print(ntsdata.shape)
print(ntrlab.shape)
print(ntslab.shape)
# Out:
# (483, 6)
# (121, 6)
# (483,)
# (121,)

# %%
model.fit(ntrdata, ntrlab)
# Out:
# LogisticRegression()

# %%
ntrpredict = model.predict(ntrdata)
ntspredict = model.predict(ntsdata)

# %%
performance(ntrlab, ntrpredict)
performance(ntslab, ntspredict)
# Out:
# acc     = 69.77
# pre     = 68.53
# recall  = 71.97
# f1    = 70.19999999999999
# acc     = 69.42
# pre     = 70.97
# recall  = 69.84
# f1    = 70.39999999999999
